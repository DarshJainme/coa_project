# %% [markdown]
# # Reason for speedup less than 1 if a single thread
#
# The speedup of less than 1 with a single thread indicates that the parallelized version of the program introduces overhead, which makes it slightly slower than the sequential version when executed with only one thread. Here are a few reasons why this happens:
#
# Parallel Overheads: Even when running with only one thread, a parallel implementation may have additional overhead such as task management, thread creation, and synchronization, which aren’t present in the purely sequential version. These extra tasks take time and can slow down execution.
#
# Setup and Scheduling: In a parallelized version, the program may still set up structures for parallel execution (e.g., dividing tasks, managing workload), even if it ends up running only one thread. This setup adds additional execution time compared to the purely sequential version.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Finding optimal block size for 100*100

# %%
exec_time=np.array([3.5406,1.82437,1.73211,1.61194,1.53543,1.25134,1.26978,1.31794,1.1903,1.21293,1.25291,1.27264,1.32821,1.37341,1.38485,1.49979,1.45565,1.48889,1.50426,1.53505,1.59699,1.61365,1.64427,1.87236,1.93533,1.94738,2.13433,1.94712,1.8345,2.22046,2.08612,2.11456])
speedup=np.array([0.969842,1.88219,1.98245,2.13024,2.23639,2.74412,2.70426,2.60545,2.88484,2.83101,2.74068,2.69819,2.5853,2.50022,2.47956,2.28954,2.35895,2.3063,2.28273,2.23695,2.15018,2.12799,2.08836,1.83395,1.77428,1.76331,1.60885,1.76354,1.8718,1.54645,1.64603,1.62389])
i=0
efficiency=[]
print(len(speedup))
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
for element in efficiency:
    print(element,end=' ')
plt.plot([i+1 for i in range(len(speedup))],speedup,label='100*100 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.title('100*100 Matrix using guided scheduling')
plt.show()

plt.plot([i+1 for i in range(len(efficiency))],efficiency)
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('100*100 Matrix using guided scheduling')
plt.show()

exec_time= np.array([0.976787,0.809406,0.696684,0.693721,0.641834,0.659724,0.726292,0.778801,0.742213,0.787296,0.839575,0.885821,0.973684,0.980831,1.03345,1.05178,1.07694,1.12258,1.14282,1.17499,1.21744,1.22893,1.26336,1.40471,1.48528,1.54059,1.65678,1.44505,1.63845,1.86477,1.75229,1.86053])
speedup=np.array([3.51542,4.24239,4.92881,4.94986,5.35001,5.20494,4.72788,4.40911,4.62646,4.36154,4.08995,3.87643,3.52663,3.50093,3.32269,3.26478,3.18849,3.05887,3.00469,2.92243,2.82053,2.79415,2.718,2.4445,2.31191,2.2289,2.07258,2.37626,2.09577,1.84141,1.95961,1.84562])
efficiency=[]
print(len(speedup))
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
for element in efficiency:
    print(element,end=' ')
plt.plot([i+1 for i in range(len(speedup))],speedup,label='100*100 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.title('100*100 Matrix with SIMD')
plt.show()

plt.plot([i+1 for i in range(len(efficiency))],efficiency)
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('100*100 Matrix with SIMD')
plt.show()
# Out:
# 32
# 0.969842 0.941095 0.6608166666666667 0.53256 0.447278 0.45735333333333333 0.38632285714285713 0.32568125 0.3205377777777778 0.283101 0.24915272727272725 0.22484916666666666 0.19886923076923077 0.17858714285714286 0.165304 0.14309625 0.13876176470588236 0.12812777777777776 0.1201436842105263 0.11184750000000002 0.10238952380952382 0.09672681818181818 0.09079826086956523 0.07641458333333333 0.0709712 0.06781961538461538 0.059587037037037036 0.06298357142857143 0.06454482758620689 0.051548333333333335 0.053097741935483875 0.0507465625
# 32
# ...

# %%
# ex_4=np.array([3.77187,2.40647,1.70943,1.90412,1.63821,1.58174,1.39069,1.47421,1.32703,1.43894,1.45721,1.52623,1.50253,1.60379,1.63634,1.65062,1.66795,1.80865,1.88722,1.86634,1.79571,1.81261,1.82185,1.71767,1.72702,1.75193,1.78278,1.82095,1.85755,2.03233,2.19443,2.21369])
# # 0.821681,1.14365,1.37739,1.66338,1.60437,1.65923,1.88397,1.93288,1.79521,2.03616,1.91269,1.85557,1.91143,1.89593,1.77267,1.7,1.76557,1.76731,1.6549,1.60089,1.51972,1.59078,1.60709,1.59882,1.59214,1.45054,1.45344,1.38916,1.47326,1.4063,1.37597,1.36156,


# ex_32=np.array([4.19133,3.06156,2.69521,1.9424,1.79928,1.81958,1.67919,1.35331,1.41068,1.48305,1.40783,1.40653,1.51665,1.46445,1.44477,1.39784,1.43342,1.5197,1.81921,1.81426,1.73429,1.91999,1.95187,1.92395,2.27139,2.13477,2.16025,1.98668,2.02504,2.20916,2.29293,2.13293])
# sp_32=np.array([0.759663,1.03999,1.18136,1.6392,1.7696,1.74985,1.89615,2.35275,2.25706,2.14693,2.26163,2.26372,2.09936,2.1742,2.20381,2.2778,2.22126,2.09514,1.75021,1.75499,1.83591,1.65834,1.63126,1.65493,1.40179,1.49149,1.4739,1.60267,1.57231,1.44127,1.38862,1.49278])
# eff_32=[]
# for i in range(len(sp_32)):
#     eff_32.append(sp_32[i]/(i+1))
# # 3.88338,2.9241,2.52773,2.25653,2.28638,1.98316,2.13475,1.94557,1.90799,1.76203,1.71861,1.95741,1.89376,2.11543,1.97433,1.83644,1.73322,1.94046,1.87655,1.8466,2.15312,2.14877,2.01483,2.21657,2.31089,2.35708,2.41413,2.39918,2.4828,2.30488,2.54631,2.64227,
# # 0.773592,1.02737,1.18848,1.33132,1.31393,1.51483,1.40726,1.5441,1.57451,1.70494,1.74801,1.53476,1.58634,1.42011,1.5216,1.63585,1.73328,1.54817,1.60089,1.62685,1.39525,1.39808,1.49102,1.35531,1.3,1.27452,1.2444,1.25216,1.20998,1.30339,1.1798,1.13696,


# ex_64=np.array([4.06589,2.96862,3.17275,2.18076,2.24104,2.21502,2.02385,2.15337,2.27805,2.08996,2.1246,2.15647,2.17941,2.18428,2.30795,2.20308,2.21801,2.03405,2.06281,2.13048,2.1829,2.43355,2.36139,2.32902,2.3357,2.46488,2.41512,5.47754,2.88168,2.55534,2.49399,2.33529])
# sp_64=np.array([0.7831,1.07255,1.00354,1.46004,1.42076,1.43745,1.57324,1.47861,1.39769,1.52347,1.49863,1.47648,1.46094,1.45768,1.37958,1.44525,1.43552,1.56535,1.54353,1.4945,1.45861,1.30838,1.34835,1.3671,1.36319,1.29174,1.31836,0.581282,1.10491,1.24602,1.27667,1.36343])
# eff_64=[]
# for i in range(len(sp_64)):
#     eff_64.append(sp_64[i]/(i+1))
# plt.plot([i+1 for i in range(len(sp_4))],sp_4,label='Block_Size=4')
# plt.plot([i+1 for i in range(len(sp_8))],sp_8,label='Block_Size=8')
# plt.plot([i+1 for i in range(len(sp_16))],sp_16,label='Block_Size=16')
# plt.plot([i+1 for i in range(len(sp_32))],sp_32,label='Block_Size=32')

# plt.plot([i+1 for i in range(len(sp_64))],sp_64,label='Block_Size=64')
# plt.title('100*100 matrix')
# plt.xlabel('Number of threads')
# plt.ylabel('Speedup')
# plt.legend()
# plt.show()
# plt.plot([i+1 for i in range(len(sp_4))],eff_4,label='Block_Size=4')
# plt.plot([i+1 for i in range(len(sp_8))],eff_8,label='Block_Size=8')
# plt.plot([i+1 for i in range(len(sp_16))],eff_16,label='Block_Size=16')
# plt.plot([i+1 for i in range(len(sp_32))],eff_32,label='Block_Size=32')

# plt.plot([i+1 for i in range(len(sp_64))],eff_64,label='Block_Size=64')

# plt.title('100*100 matrix')
# plt.xlabel('Number of threads')
# plt.ylabel('Efficiency')
# plt.legend()
# plt.show()
ex_4=np.array([4.10429,2.43875,1.99228,1.65795,1.60254,1.53548,1.37158,1.40729,1.37711,1.47539,1.48362,1.58348,1.60805,1.59202,1.56123,1.55093,1.6616,1.68916,1.64253,1.98202,1.96752,1.87664,1.76579,1.88012,1.97826,1.90345,1.8872,1.98879,2.07522,2.11728,2.1207,2.1797])
sp_4=np.array([0.836641,1.40802,1.72356,2.07112,2.14273,2.23631,2.50355,2.44002,2.49349,2.32739,2.31449,2.16853,2.1354,2.15689,2.19943,2.21403,2.06658,2.03286,2.09057,1.73249,1.74525,1.82977,1.94463,1.82638,1.73578,1.804,1.81953,1.72658,1.65468,1.62181,1.61919,1.57537])
eff_4=[]
for i in range(len(sp_4)):
    eff_4.append(sp_4[i]/(i+1))
ex_8=np.array([3.94842,2.54663,2.31066,1.76868,1.74107,1.57667,1.52688,1.36967,1.27629,1.2539,1.51078,1.36475,1.45488,1.52388,1.49741,1.60459,1.59728,1.58823,1.84018,1.83459,1.88075,1.78879,1.76736,1.79828,1.85989,1.81948,1.94164,2.02021,2.05527,2.12436,2.19957,2.29062])
sp_8=np.array([0.869669,1.34838,1.48608,1.94146,1.97224,2.1779,2.24892,2.50704,2.69048,2.7385,2.27288,2.51608,2.36021,2.25334,2.29317,2.14,2.14979,2.16204,1.86602,1.87171,1.82577,1.91963,1.94291,1.90951,1.84624,1.88726,1.76851,1.69974,1.67074,1.6164,1.56113,1.49908])
eff_8=[]
for i in range(len(sp_8)):
    eff_8.append(sp_8[i]/(i+1))
# 3.81632,2.80709,1.97148,1.81102,1.70063,1.49529,1.38923,1.34569,1.35434,1.53322,1.38847,1.46218,1.55748,1.52676,1.48238,1.71752,1.75971,1.76247,2.21122,1.87974,2.0266,2.01029,1.97942,2.04002,2.17908,1.86264,2.06247,2.02339,2.16578,2.25203,2.37211,2.39763,
# 0.787185,1.0702,1.52381,1.65881,1.76649,2.00908,2.16246,2.23241,2.21816,1.95937,2.16364,2.05457,1.92885,1.96766,2.02657,1.74912,1.70718,1.70451,1.35859,1.59817,1.48236,1.49439,1.51769,1.4726,1.37863,1.61284,1.45658,1.48471,1.3871,1.33397,1.26644,1.25296,
#for 8 size

ex_16=np.array([3.96606,2.42703,1.96869,1.79957,1.59818,1.46364,1.48638,1.39319,1.34778,1.42063,1.27674,1.19111,1.48962,1.5372,1.67119,1.60277,1.62302,1.51426,1.41602,1.70299,1.46983,1.51209,1.74131,1.85786,1.6674,1.90179,1.96685,2.05195,2.0468,2.10766,2.11911,2.19888])
t.plot([i+1 for i in range(len(sp_16))],sp_16,label='Block_Size=16')
plt.plot([i+1 for i in range(len(sp_32))],sp_32,label='Block_Size=32')
plt.plot([i+1 for i in range(len(sp_64))],sp_64,label='Block_Size=64')
plt.title('100*100 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.legend()
plt.show()
plt.plot([i+1 for i in range(len(eff_4))],eff_4,label='Block_Size=4')
plt.plot([i+1 for i in range(len(eff_8))],eff_8,label='Block_Size=8')
plt.plot([i+1 for i in range(len(eff_16))],eff_16,label='Block_Size=16')
plt.plot([i+1 for i in range(len(eff_32))],eff_32,label='Block_Size=32')
plt.plot([i+1 for i in range(len(eff_64))],eff_64,label='Block_Size=64')
plt.title('100*100 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.legend()
plt.show()

# %% [markdown]
# # Finding optimal block size for 1000*1000 matrix

# %%
exec_time=np.array([2.20462,1.093,0.725836,0.55356,0.499478,0.44654,0.405656,0.379084,0.367109,0.352281,0.338665,0.338746,0.336902,0.330778,0.332153,0.332532,0.332783,0.340136,0.33844,0.33712,0.348942,0.33795,0.337412,0.35479,0.343258,0.339783,0.341065,0.365409,0.410383,0.343543,0.343774,0.371792])
speedup=np.array([0.99382,2.00458,3.01858,3.958,4.38657,4.9066,5.40112,5.77971,5.96823,6.21945,6.4695,6.46795,6.50336,6.62377,6.59633,6.58881,6.58385,6.44152,6.47381,6.49915,6.27895,6.48319,6.49353,6.17546,6.38293,6.44821,6.42398,5.996,5.3389,6.37764,6.37336,5.89306])

efficiency=[]
print(len(speedup))
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
for element in efficiency:
    print(element,end=' ')
plt.plot([i+1 for i in range(len(speedup))],speedup)
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.title('1000*1000 Matrix using guided scheduling')
plt.show()
plt.plot([i+1 for i in range(len(efficiency))],efficiency)
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('1000*1000 Matrix using guided scheduling')
plt.show()

efficiency=np.array([0.566013,0.276496,0.178236,0.138024,0.137794,0.125854,0.121587,0.10841,0.105285,0.101516,0.0987416,0.0972824,0.0964429,0.0940388,0.0977205,0.0978088,0.0962755,0.0966773,0.0992805,0.106625,0.109998,0.0985212,0.0989066,0.106493,0.0992778,0.13303,0.0996724,0.129117,0.120244,0.101009,0.120782,0.117707])
speedup=np.array([3.87092,7.92415,12.2927,15.874,15.9005,17.409,18.02,20.2103,20.8101,21.5827,22.1892,22.522,22.718,23.2988,22.421,22.4008,22.7575,22.663,22.0687,20.5486,19.9185,22.2388,22.1521,20.574,22.0693,16.4699,21.9819,16.969,18.2212,21.691,18.14,18.614])
i=0
efficiency=[]
print(len(speedup))
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
for element in efficiency:
    print(element,end=' ')
plt.plot([i+1 for i in range(len(speedup))],speedup,label='100*100 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.title('1000*1000 Matrix with SIMD')
plt.show()

plt.plot([i+1 for i in range(len(efficiency))],efficiency)
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('1000*1000 Matrix with SIMD')
plt.show()
# Out:
# 32
# 0.99382 1.00229 1.0061933333333333 0.9895 0.8773139999999999 0.8177666666666666 0.7715885714285714 0.72246375 0.6631366666666667 0.621945 0.5881363636363637 0.5389958333333333 0.5002584615384615 0.4731264285714286 0.43975533333333333 0.411800625 0.38728529411764706 0.3578622222222222 0.34072684210526316 0.3249575 0.29899761904761907 0.2946904545454545 0.2823273913043478 0.2573108333333333 0.2553172 0.24800807692307694 0.23792518518518518 0.21414285714285716 0.18409999999999999 0.21258800000000003 0.20559225806451611 0.184158125
# 32
# ...

# %% [markdown]
# # Why does SIMD increase speedup drastically?
#
# SIMD is a form of data-level parallelism, where the same operation is applied simultaneously across multiple data points. This approach is highly effective for repetitive calculations like those in the Laplacian solver, where each computation is independent and can be performed in parallel.

# %% [markdown]
# # Reason for getting a speedup plateau
# Physical Cores vs. Threads
#
# Physical cores: These are the actual processing units on a CPU, each capable of executing one task at a time.
#
# Threads: A thread is a path of execution for a process. In a multi-threaded program, multiple threads can be used to execute tasks concurrently.
# Most modern CPUs support multi-threading (often called hyper-threading on Intel processors), which allows each physical core to handle more than one thread. For example, a 4-core CPU with hyper-threading might support 8 threads. However, multi-threading does not double the processing power; it only improves resource utilization when there are idle CPU cycles.
#
# True Parallelism vs. Context Switching
# When we run a program with threads equal to or fewer than the available physical cores (e.g., 4 threads on a 4-core CPU), each thread can be assigned to its own core. This allows true parallelism, where each thread can run simultaneously without needing to share processing time with other threads.
#
# When the number of threads exceeds the number of physical cores (e.g., 8 threads on a 4-core CPU), the system can’t provide each thread with its own dedicated core. Instead, it needs to time-share each core among multiple threads, a process managed by the operating system.
#
# How Context Switching Works
# Context switching is the process by which the operating system quickly switches between threads on the same core. This switching happens so fast that it can give the appearance of simultaneous execution.
# However, context switching has an overhead: each time the CPU switches from one thread to another, it needs to save the state of the current thread and load the state of the next one. This takes time and consumes CPU resources, which can slow down performance.
# Why Speedup Plateaus
# When our program has more threads than cores:
#
# Higher Context-Switching Overhead: With more threads than physical cores, the CPU spends more time switching between threads rather than executing actual work. The added overhead limits speedup because the CPU is frequently interrupted to manage multiple threads on the same core.
#
# Limited CPU Resources per Thread: Physical cores are the real source of computational power. When multiple threads share the same core, they are no longer running truly in parallel; instead, they’re taking turns, which dilutes the effectiveness of additional threads. Therefore, after a certain number of threads, we get diminishing returns as the performance benefit of adding threads is offset by the lack of available cores.
#
# Diminished Performance Gains: Initially, adding threads to a multi-threaded program increases speedup because it allows better utilization of all available cores. However, once all cores are fully utilized, adding more threads doesn’t increase the computational power. Instead, it just introduces more context switching and contention for core time, leading to a plateau or even a decrease in speedup.

# %%
ex_4=np.array([2.46268,1.26839,0.865714,0.712443,0.636753,0.568882,0.513702,0.492549,0.48,0.465194,0.452899,0.452765,0.442947,0.448096,0.44348,0.44033,0.44781,0.442122,0.440898,0.426897,0.431044,0.455648,0.465924,0.44695,0.44319,0.444555,0.439292,0.441192,0.43025,0.434517,0.429537,0.436392])
sp_4=np.array([0.874913,1.69872,2.48885,3.02428,3.38378,3.78748,4.19432,4.37445,4.48881,4.63168,4.75742,4.75883,4.8643,4.80841,4.85847,4.89321,4.81148,4.87339,4.88691,5.04719,4.99863,4.72872,4.62443,4.82075,4.86164,4.84671,4.90479,4.88366,5.00786,4.95868,5.01617,4.93737])
eff_4=[]
for i in range(len(sp_4)):
    eff_4.append(sp_4[i]/(i+1))
ex_8=np.array([2.76514,1.32922,0.89816,0.703266,0.61629,0.528761,0.485787,0.469856,0.496775,0.463985,0.455809,0.47346,0.426308,0.424278,0.422354,0.429848,0.415618,0.418807,0.412678,0.414488,0.405724,0.430328,0.483873,0.448853,0.437359,0.445272,0.5023,0.432357,0.480552,0.458938,0.437741,0.47681])
eff_256=[]
for i in range(len(sp_256)):
    eff_256.append(sp_256[i]/(i+1))
ex_512=np.array([2.41609,1.27254,1.27656,0.693943,0.685582,0.739885,0.757903,0.754779,0.756062,0.770643,0.743259,0.753477,0.740374,0.73079,0.728857,0.752276,0.714737,0.738703,0.856846,0.881268,0.883035,0.817437,0.887013,0.83787,0.862527,0.832565,0.804431,0.773014,0.82524,0.751317,0.831536,0.813555])
sp_512=np.array([0.906834,1.72175,1.71632,3.15731,3.19582,2.96126,2.89086,2.90283,2.8979,2.84307,2.94782,2.90784,2.9593,2.99811,3.00607,2.91249,3.06545,2.966,2.55704,2.48618,2.48121,2.68032,2.47008,2.61496,2.5402,2.63162,2.72366,2.83435,2.65498,2.9162,2.63487,2.69311])
eff_512=[]
for i in range(len(sp_512)):
    eff_512.append(sp_512[i]/(i+1))
plt.plot([i+1 for i in range(len(sp_4))],sp_4,label='Block_Size=4')
plt.plot([i+1 for i in range(len(sp_8))],sp_8,label='Block_Size=8')
plt.plot([i+1 for i in range(len(sp_16))],sp_16,label='Block_Size=16')
plt.plot([i+1 for i in range(len(sp_32))],sp_32,label='Block_Size=32')
plt.plot([i+1 for i in range(len(sp_64))],sp_64,label='Block_Size=64')
plt.plot([i+1 for i in range(len(sp_128))],sp_128,label='Block_Size=128')
plt.plot([i+1 for i in range(len(sp_256))],sp_256,label='Block_Size=256')
plt.plot([i+1 for i in range(len(sp_512))],sp_512,label='Block_Size=512')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.title('1000*1000 matrix with tiling')
plt.legend()
plt.show()
plt.plot([i+1 for i in range(len(eff_4))],eff_4,label='Block_Size=4')
plt.plot([i+1 for i in range(len(eff_8))],eff_8,label='Block_Size=8')
plt.plot([i+1 for i in range(len(eff_16))],eff_16,label='Block_Size=16')
plt.plot([i+1 for i in range(len(eff_32))],eff_32,label='Block_Size=32')
plt.plot([i+1 for i in range(len(eff_64))],eff_64,label='Block_Size=64')
plt.plot([i+1 for i in range(len(eff_128))],eff_128,label='Block_Size=128')
plt.plot([i+1 for i in range(len(eff_256))],eff_256,label='Block_Size=256')
plt.plot([i+1 for i in range(len(eff_512))],eff_512,label='Block_Size=512')
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('1000*1000 matrix with tiling')
plt.legend()
plt.show()

# %% [markdown]
# # Why does speedup remains the same on increasing the block size?​
#
# Speedup remains the same after a certain block size because the benefits of tiling saturate while the overheads stabilize as beyond a certain block size, the memory system reaches its bandwidth limit. Even if computations continue to scale, the rate of data transfer cannot increase further, resulting in no additional speedup. When the block size is small, cache efficiency improves significantly. However, once the block size optimally utilizes the cache, increasing it further causes no effect.​
#
# # Why does after a particular block size the speedup decreases?​
#
# When we process larger blocks, more data is required simultaneously. As block size increases, the number of blocks decreases. If there are fewer blocks than available threads, some threads will remain idle, reducing overall parallel efficiency. If the block size exceeds the available cache, the working set no longer fits in the cache, leading to cache thrashing, leading to frequent cache misses and slower memory access.

# %%
exec_time=np.array([2.2224,1.06703,0.730208,0.584562,0.552528,0.509069,0.504423,0.464002,0.432588,0.412145,0.439331,0.447042,0.398718,0.413799,0.367809,0.375802,0.371767,0.397152,0.386127,0.383051,0.371436,0.365617,0.37234,0.370175,0.369113,0.372274,0.36444,0.382505,0.371182,0.365908,0.368578,0.386735])
speedup=np.array([0.96606,2.0121,2.94022,3.67279,3.88572,4.21745,4.25629,4.62707,4.96309,5.20927,4.88691,4.80262,5.38469,5.18845,5.83719,5.71305,5.77505,5.40592,5.56027,5.60492,5.7802,5.87219,5.76616,5.79989,5.81657,5.76718,5.89116,5.61293,5.78415,5.86752,5.82501,5.55153])
i=0
efficiency=[]
print(len(speedup))
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
for element in efficiency:
    print(element,end=' ')
plt.plot([i+1 for i in range(len(speedup))],speedup,label='10000*10000 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.title('10000*10000 Matrix using guided scheduling')
plt.show()

plt.plot([i+1 for i in range(len(efficiency))],efficiency)
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('10000*10000 Matrix using guided scheduling')
plt.show()

exec_time= np.array([0.572869,0.273309,0.182748,0.142894,0.127851,0.133262,0.119817,0.121175,0.112312,0.106578,0.122018,0.113168,0.101756,0.105887,0.0983081,0.105458,0.0973507,0.102685,0.102109,0.10226,0.099068,0.0974551,0.0959444,0.0971819,0.0963502,0.0987068,0.0984101,0.100089,0.0989078,0.0979684,0.096737,0.0984465])
speedup=np.array([3.74775,7.85547,11.7483,15.025,16.7928,16.1109,17.9187,17.7179,19.1161,20.1446,17.5956,18.9716,21.0992,20.2761,21.8392,20.3585,22.054,20.9083,21.0263,20.9952,21.6717,22.0304,22.3773,22.0923,22.283,21.751,21.8166,21.4507,21.7068,21.9149,22.1939,21.8085])

efficiency=[]
print(len(speedup))
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
for element in efficiency:
    print(element,end=' ')
plt.plot([i+1 for i in range(len(speedup))],speedup,label='10000*10000 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.title('10000*10000 Matrix with SIMD')
plt.show()

plt.plot([i+1 for i in range(len(efficiency))],efficiency)
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('10000*10000 Matrix with SIMD')
plt.show()
# Out:
# 32
# 0.96606 1.00605 0.9800733333333334 0.9181975 0.7771440000000001 0.7029083333333334 0.6080414285714285 0.57838375 0.5514544444444445 0.520927 0.44426454545454547 0.40021833333333334 0.4142069230769231 0.3706035714285714 0.389146 0.357065625 0.3397088235294118 0.30032888888888887 0.2926457894736842 0.280246 0.275247619047619 0.2669177272727273 0.2507026086956522 0.24166208333333336 0.23266279999999998 0.2218146153846154 0.2181911111111111 0.20046178571428572 0.1994534482758621 0.195584 0.18790354838709677 0.1734853125
# 32
# ...

# %% [markdown]
# # Finding optimal value for 10000*10000 matrix

# %%
# ex_2=np.array([2.39118,1.19077,0.802517,0.594768,0.562162,0.533806,0.47338,0.451343,0.430309,0.400641,0.367174,0.351475,0.370679,0.36161,0.361609,0.361881,0.369975,0.366298,0.355644,0.368717,0.368819,0.374381,0.359762,0.36515,0.360125,0.361122,0.360204,0.36259,0.363314,0.363624,0.360956,0.36811])
# sp_2=np.array([0.867195,1.74142,2.5839,3.48644,3.68866,3.8846,4.38046,4.59434,4.81892,5.17576,5.64752,5.89978,5.59412,5.73442,5.73443,5.73012,5.60476,5.66103,5.83061,5.62389,5.62233,5.5388,5.76387,5.67882,5.75807,5.74217,5.75681,5.71892,5.70752,5.70266,5.74481,5.63317])
# eff_2=[]
# for i in range(len(sp_2)):
#     eff_2.append(sp_2[i]/(i+1))
# # 0.821681,1.14365,1.37739,1.66338,1.60437,1.65923,1.88397,1.93288,1.79521,2.03616,1.91269,1.85557,1.91143,1.89593,1.77267,1.7,1.76557,1.76731,1.6549,1.60089,1.51972,1.59078,1.60709,1.59882,1.59214,1.45054,1.45344,1.38916,1.47326,1.4063,1.37597,1.36156,


# ex_32=np.array([2.25996,1.12101,0.77577,0.617952,0.556317,0.546826,0.486308,0.452097,0.433753,0.406019,0.365406,0.368961,0.374554,0.371376,0.381774,0.389296,0.376159,0.370945,0.362371,0.356037,0.352251,0.349856,0.357244,0.3662,0.403805,0.386107,0.389988,0.35439,0.362427,0.374348,0.368639,0.363692])
# sp_32=np.array([0.917548,1.84979,2.67299,3.35564,3.72741,3.79211,4.26401,4.58667,4.78065,5.1072,5.67484,5.62016,5.53624,5.58362,5.43155,5.3266,5.51262,5.59011,5.72237,5.82417,5.88678,5.92708,5.8045,5.66254,5.1352,5.3706,5.31714,5.85125,5.72149,5.53929,5.62507,5.7016])
# eff_32=[]
# for i in range(len(sp_32)):
#     eff_32.append(sp_32[i]/(i+1))
# # 3.88338,2.9241,2.52773,2.25653,2.28638,1.98316,2.13475,1.94557,1.90799,1.76203,1.71861,1.95741,1.89376,2.11543,1.97433,1.83644,1.73322,1.94046,1.87655,1.8466,2.15312,2.14877,2.01483,2.21657,2.31089,2.35708,2.41413,2.39918,2.4828,2.30488,2.54631,2.64227,
# # 0.773592,1.02737,1.18848,1.33132,1.31393,1.51483,1.40726,1.5441,1.57451,1.70494,1.74801,1.53476,1.58634,1.42011,1.5216,1.63585,1.73328,1.54817,1.60089,1.62685,1.39525,1.39808,1.49102,1.35531,1.3,1.27452,1.2444,1.25216,1.20998,1.30339,1.1798,1.13696,


# plt.plot([i+1 for i in range(len(sp_2))],sp_2,label='Block_Size=2')
# plt.plot([i+1 for i in range(len(sp_4))],sp_4,label='Block_Size=4')
# plt.plot([i+1 for i in range(len(sp_8))],sp_8,label='Block_Size=8')
# plt.plot([i+1 for i in range(len(sp_16))],sp_16,label='Block_Size=16')
# plt.plot([i+1 for i in range(len(sp_32))],sp_32,label='Block_Size=32')
# plt.legend()
# plt.show()
# plt.plot([i+1 for i in range(len(sp_2))],eff_2,label='Block_Size=2')
# plt.plot([i+1 for i in range(len(sp_4))],eff_4,label='Block_Size=4')
# plt.plot([i+1 for i in range(len(sp_8))],eff_8,label='Block_Size=8')
# plt.plot([i+1 for i in range(len(sp_16))],eff_16,label='Block_Size=16')
# plt.plot([i+1 for i in range(len(sp_32))],eff_32,label='Block_Size=32')
# plt.legend()
# plt.show()


ex_4=np.array([2.5166,1.21283,0.853837,0.714994,0.68223,0.591058,0.558856,0.515504,0.486463,0.486719,0.512792,0.481365,0.500766,0.420173,0.43122,0.433438,0.429099,0.45278,0.439672,0.426075,0.421302,0.4167,0.417047,0.424,0.417781,0.424763,0.42268,0.423363,0.418142,0.427644,0.431948,0.418366])
ex_256=np.array([2.51021,1.28635,0.872178,0.801882,0.692992,0.602031,0.534731,0.511991,0.481765,0.456027,0.453258,0.44299,0.413052,0.439736,0.463891,0.495453,0.492238,0.49241,0.435378,0.403255,0.41571,0.401965,0.440325,0.444764,0.438477,0.45869,0.397103,0.406046,0.422005,0.434318,0.435928,0.430029])
sp_256=np.array([0.855295,1.66905,2.46162,2.67742,3.09812,3.56622,4.01505,4.19338,4.45647,4.70799,4.73676,4.84655,5.19782,4.88241,4.62819,4.33335,4.36165,4.36013,4.93128,5.32411,5.16459,5.3412,4.87588,4.82722,4.89643,4.68066,5.40659,5.28751,5.08755,4.94332,4.92507,4.99263])
eff_256=[]
for i in range(len(sp_256)):
    eff_256.append(sp_256[i]/(i+1))
ex_512=np.array([2.46214,1.22611,0.912837,0.755741,0.664815,0.586622,0.553065,0.51292,0.482484,0.454269,0.422761,0.402316,0.406591,0.398229,0.429682,0.444543,0.458265,0.430077,0.435123,0.405506,0.413033,0.420944,0.427352,0.433829,0.417485,0.433896,0.426595,0.412233,0.400904,0.404338,0.422371,0.431785])
sp_512=np.array([0.871993,1.75105,2.35198,2.84088,3.22943,3.65989,3.88195,4.18578,4.44983,4.72621,5.07846,5.33653,5.28042,5.3913,4.99666,4.82962,4.685,4.99207,4.93417,5.29455,5.19807,5.10037,5.0239,4.94889,5.14264,4.94812,5.03281,5.20816,5.35532,5.30984,5.08314,4.97231])
eff_512=[]
for i in range(len(sp_512)):
    eff_512.append(sp_512[i]/(i+1))
plt.plot([i+1 for i in range(len(sp_4))],sp_4,label='Block_Size=4')
plt.plot([i+1 for i in range(len(sp_8))],sp_8,label='Block_Size=8')
plt.plot([i+1 for i in range(len(sp_16))],sp_16,label='Block_Size=16')
plt.plot([i+1 for i in range(len(sp_32))],sp_32,label='Block_Size=32')
plt.plot([i+1 for i in range(len(sp_64))],sp_64,label='Block_Size=64')
plt.plot([i+1 for i in range(len(sp_128))],sp_128,label='Block_Size=128')
plt.plot([i+1 for i in range(len(sp_256))],sp_256,label='Block_Size=256')
plt.plot([i+1 for i in range(len(sp_512))],sp_512,label='Block_Size=512')
plt.title('10000*10000 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.legend()
plt.show()
plt.plot([i+1 for i in range(len(eff_4))],eff_4,label='Block_Size=4')
plt.plot([i+1 for i in range(len(eff_8))],eff_8,label='Block_Size=8')
plt.plot([i+1 for i in range(len(eff_16))],eff_16,label='Block_Size=16')
plt.plot([i+1 for i in range(len(eff_32))],eff_32,label='Block_Size=32')
plt.plot([i+1 for i in range(len(eff_64))],eff_64,label='Block_Size=64')
plt.plot([i+1 for i in range(len(eff_128))],eff_128,label='Block_Size=128')
plt.plot([i+1 for i in range(len(eff_256))],eff_256,label='Block_Size=256')
plt.plot([i+1 for i in range(len(eff_512))],eff_512,label='Block_Size=512')
plt.title('10000*10000 matrix')
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt
# 32
# ...

# %% [markdown]
# # 10000*10000 Matrix

# %%
# 10000* 10000 matrix
exec_time=np.array([2.2224,1.06703,0.730208,0.584562,0.552528,0.509069,0.504423,0.464002,0.432588,0.412145,0.439331,0.447042,0.398718,0.413799,0.367809,0.375802,0.371767,0.397152,0.386127,0.383051,0.371436,0.365617,0.37234,0.370175,0.369113,0.372274,0.36444,0.382505,0.371182,0.365908,0.368578,0.386735])
speedup=np.array([0.96606,2.0121,2.94022,3.67279,3.88572,4.21745,4.25629,4.62707,4.96309,5.20927,4.88691,4.80262,5.38469,5.18845,5.83719,5.71305,5.77505,5.40592,5.56027,5.60492,5.7802,5.87219,5.76616,5.79989,5.81657,5.76718,5.89116,5.61293,5.78415,5.86752,5.82501,5.55153])

i=0

for element in efficiency:
    print(element,end=' ')
plt.plot([i+1 for i in range(len(speedup))],speedup,label='Using Guided Scheduling')


ex_16=np.array([2.44508,1.25848,0.820396,0.68062,0.644509,0.586276,0.551227,0.568117,0.49622,0.490568,0.432431,0.410788,0.412991,0.407986,0.411478,0.451351,0.421035,0.426877,0.426556,0.467932,0.444141,0.429612,0.426519,0.420341,0.420342,0.4273,0.418224,0.409519,0.413883,0.407843,0.417151,0.421105])
sp_16=np.array([0.878079,1.70601,2.61699,3.15444,3.33117,3.66205,3.8949,3.7791,4.32666,4.3765,4.96489,5.22648,5.19859,5.26236,5.21771,4.75677,5.09927,5.02949,5.03327,4.58822,4.83399,4.99747,5.03371,5.10769,5.10768,5.02451,5.13355,5.24267,5.18739,5.26421,5.14675,5.09843])
eff_16=[]
for i in range(len(sp_16)):
    eff_16.append(sp_16[i]/(i+1))

plt.plot([i+1 for i in range(len(sp_16))],sp_16,label='With Tiling and Block size=16')
exec_time= np.array([0.572869,0.273309,0.182748,0.142894,0.127851,0.133262,0.119817,0.121175,0.112312,0.106578,0.122018,0.113168,0.101756,0.105887,0.0983081,0.105458,0.0973507,0.102685,0.102109,0.10226,0.099068,0.0974551,0.0959444,0.0971819,0.0963502,0.0987068,0.0984101,0.100089,0.0989078,0.0979684,0.096737,0.0984465])
speedup=np.array([3.74775,7.85547,11.7483,15.025,16.7928,16.1109,17.9187,17.7179,19.1161,20.1446,17.5956,18.9716,21.0992,20.2761,21.8392,20.3585,22.054,20.9083,21.0263,20.9952,21.6717,22.0304,22.3773,22.0923,22.283,21.751,21.8166,21.4507,21.7068,21.9149,22.1939,21.8085])

for element in efficiency:
    print(element,end=' ')
plt.plot([i+1 for i in range(len(speedup))],speedup,label='With SIMD')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.title('10000*10000 Matrix')

plt.legend()

plt.show()



#******************************************************************************

exec_time=np.array([2.2224,1.06703,0.730208,0.584562,0.552528,0.509069,0.504423,0.464002,0.432588,0.412145,0.439331,0.447042,0.398718,0.413799,0.367809,0.375802,0.371767,0.397152,0.386127,0.383051,0.371436,0.365617,0.37234,0.370175,0.369113,0.372274,0.36444,0.382505,0.371182,0.365908,0.368578,0.386735])
speedup=np.array([0.96606,2.0121,2.94022,3.67279,3.88572,4.21745,4.25629,4.62707,4.96309,5.20927,4.88691,4.80262,5.38469,5.18845,5.83719,5.71305,5.77505,5.40592,5.56027,5.60492,5.7802,5.87219,5.76616,5.79989,5.81657,5.76718,5.89116,5.61293,5.78415,5.86752,5.82501,5.55153])
i=0
efficiency=[]
print(len(speedup))
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
for element in efficiency:
    print(element,end=' ')


plt.plot([i+1 for i in range(len(efficiency))],efficiency,label='Using Guided Scheduling')
plt.plot([i+1 for i in range(len(eff_16))],eff_16,label='With Tiling and Block size=16')


exec_time= np.array([0.572869,0.273309,0.182748,0.142894,0.127851,0.133262,0.119817,0.121175,0.112312,0.106578,0.122018,0.113168,0.101756,0.105887,0.0983081,0.105458,0.0973507,0.102685,0.102109,0.10226,0.099068,0.0974551,0.0959444,0.0971819,0.0963502,0.0987068,0.0984101,0.100089,0.0989078,0.0979684,0.096737,0.0984465])
speedup=np.array([3.74775,7.85547,11.7483,15.025,16.7928,16.1109,17.9187,17.7179,19.1161,20.1446,17.5956,18.9716,21.0992,20.2761,21.8392,20.3585,22.054,20.9083,21.0263,20.9952,21.6717,22.0304,22.3773,22.0923,22.283,21.751,21.8166,21.4507,21.7068,21.9149,22.1939,21.8085])
efficiency=[]
print(len(speedup))
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
for element in efficiency:
    print(element,end=' ')

plt.plot([i+1 for i in range(len(efficiency))],efficiency,label='With SIMD')
plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('With SIMD')


plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.title('10000*10000 Matrix ')
plt.legend()



plt.show()
# Out:
# 3.87092 3.962075 4.097566666666666 3.9685 3.1801 2.9015 2.5742857142857143 2.5262875 2.3122333333333334 2.15827 2.0172 1.8768333333333331 1.7475384615384615 1.6642 1.4947333333333332 1.40005 1.3386764705882352 1.2590555555555556 1.1615105263157894 1.02743 0.9485000000000001 1.0108545454545455 0.9631347826086957 0.8572500000000001 0.8827719999999999 0.6334576923076922 0.8141444444444444 0.6060357142857143 0.6283172413793103 0.7230333333333333 0.5851612903225807 0.5816875 3.87092 3.962075 4.097566666666666 3.9685 3.1801 2.9015 2.5742857142857143 2.5262875 2.3122333333333334 2.15827 2.0172 1.8768333333333331 1.7475384615384615 1.6642 1.4947333333333332 1.40005 1.3386764705882352 1.2590555555555556 1.1615105263157894 1.02743 0.9485000000000001 1.0108545454545455 0.9631347826086957 0.8572500000000001 0.8827719999999999 0.6334576923076922 0.8141444444444444 0.6060357142857143 0.6283172413793103 0.7230333333333333 0.5851612903225807 0.5816875
# 32
# ...

# %%
# 100* 100 matrix
exec_time=np.array([3.5406,1.82437,1.73211,1.61194,1.53543,1.25134,1.26978,1.31794,1.1903,1.21293,1.25291,1.27264,1.32821,1.37341,1.38485,1.49979,1.45565,1.48889,1.50426,1.53505,1.59699,1.61365,1.64427,1.87236,1.93533,1.94738,2.13433,1.94712,1.8345,2.22046,2.08612,2.11456])
speedup=np.array([0.969842,1.88219,1.98245,2.13024,2.23639,2.74412,2.70426,2.60545,2.88484,2.83101,2.74068,2.69819,2.5853,2.50022,2.47956,2.28954,2.35895,2.3063,2.28273,2.23695,2.15018,2.12799,2.08836,1.83395,1.77428,1.76331,1.60885,1.76354,1.8718,1.54645,1.64603,1.62389])
i=0

plt.plot([i+1 for i in range(len(speedup))],speedup,label
# eff_16=[]
# for i in range(len(sp_16)):
#     eff_16.append(sp_16[i]/(i+1))

# %%
# 100* 100 matrix

exec_time= np.array([0.976787,0.809406,0.696684,0.693721,0.641834,0.659724,0.726292,0.778801,0.742213,0.787296,0.839575,0.885821,0.973684,0.980831,1.03345,1.05178,1.07694,1.12258,1.14282,1.17499,1.21744,1.22893,1.26336,1.40471,1.48528,1.54059,1.65678,1.44505,1.63845,1.86477,1.75229,1.86053])
speedup=np.array([3.51542,4.24239,4.92881,4.94986,5.35001,5.20494,4.72788,4.40911,4.62646,4.36154,4.08995,3.87643,3.52663,3.50093,3.32269,3.26478,3.18849,3.05887,3.00469,2.92243,2.82053,2.79415,2.718,2.4445,2.31191,2.2289,2.07258,2.37626,2.09577,1.84141,1.95961,1.84562])
i=0

plt.plot([i+1 for i in range(len(speedup))],speedup,label='100*100 Matrix')


efficiency=np.array([0.566013,0.276496,0.178236,0.138024,0.137794,0.125854,0.121587,0.10841,0.105285,0.101516,0.0987416,0.0972824,0.0964429,0.0940388,0.0977205,0.0978088,0.0962755,0.0966773,0.0992805,0.106625,0.109998,0.0985212,0.0989066,0.106493,0.0992778,0.13303,0.0996724,0.129117,0.120244,0.101009,0.120782,0.117707])
speedup=np.array([3.87092,7.92415,12.2927,15.874,15.9005,17.409,18.02,20.2103,20.8101,21.5827,22.1892,22.522,22.718,23.2988,22.421,22.4008,22.7575,22.663,22.0687,20.5486,19.9185,22.2388,22.1521,20.574,22.0693,16.4699,21.9819,16.969,18.2212,21.691,18.14,18.614])

i=0

plt.plot([i+1 for i in range(len(speedup))],speedup,label='1000*1000 Matrix')
exec_time= np.array([0.572869,0.273309,0.182748,0.142894,0.127851,0.133262,0.119817,0.121175,0.112312,0.106578,0.122018,0.113168,0.101756,0.105887,0.0983081,0.105458,0.0973507,0.102685,0.102109,0.10226,0.099068,0.0974551,0.0959444,0.0971819,0.0963502,0.0987068,0.0984101,0.100089,0.0989078,0.0979684,0.096737,0.0984465])
speedup=np.array([3.74775,7.85547,11.7483,15.025,16.7928,16.1109,17.9187,17.7179,19.1161,20.1446,17.5956,18.9716,21.0992,20.2761,21.8392,20.3585,22.054,20.9083,21.0263,20.9952,21.6717,22.0304,22.3773,22.0923,22.283,21.751,21.8166,21.4507,21.7068,21.9149,22.1939,21.8085])

i=0

plt.plot([i+1 for i in range(len(speedup))],speedup,label='10000*10000 Matrix')

plt.title('With SIMD')
plt.xlabel('Number of threads')
plt.ylabel('Speedup')
plt.legend()

plt.show()


exec_time= np.array([0.976787,0.809406,0.696684,0.693721,0.641834,0.659724,0.726292,0.778801,0.742213,0.787296,0.839575,0.885821,0.973684,0.980831,1.03345,1.05178,1.07694,1.12258,1.14282,1.17499,1.21744,1.22893,1.26336,1.40471,1.48528,1.54059,1.65678,1.44505,1.63845,1.86477,1.75229,1.86053])
speedup=np.array([3.51542,4.24239,4.92881,4.94986,5.35001,5.20494,4.72788,4.40911,4.62646,4.36154,4.08995,3.87643,3.52663,3.50093,3.32269,3.26478,3.18849,3.05887,3.00469,2.92243,2.82053,2.79415,2.718,2.4445,2.31191,2.2289,2.07258,2.37626,2.09577,1.84141,1.95961,1.84562])
i=0
efficiency=[]
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
plt.plot([i+1 for i in range(len(efficiency))],efficiency,label='100*100 Matrix')


efficiency=np.array([0.566013,0.276496,0.178236,0.138024,0.137794,0.125854,0.121587,0.10841,0.105285,0.101516,0.0987416,0.0972824,0.0964429,0.0940388,0.0977205,0.0978088,0.0962755,0.0966773,0.0992805,0.106625,0.109998,0.0985212,0.0989066,0.106493,0.0992778,0.13303,0.0996724,0.129117,0.120244,0.101009,0.120782,0.117707])
speedup=np.array([3.87092,7.92415,12.2927,15.874,15.9005,17.409,18.02,20.2103,20.8101,21.5827,22.1892,22.522,22.718,23.2988,22.421,22.4008,22.7575,22.663,22.0687,20.5486,19.9185,22.2388,22.1521,20.574,22.0693,16.4699,21.9819,16.969,18.2212,21.691,18.14,18.614])

i=0
efficiency=[]
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors

plt.plot([i+1 for i in range(len(efficiency))],efficiency,label='1000*1000 Matrix')
exec_time= np.array([0.572869,0.273309,0.182748,0.142894,0.127851,0.133262,0.119817,0.121175,0.112312,0.106578,0.122018,0.113168,0.101756,0.105887,0.0983081,0.105458,0.0973507,0.102685,0.102109,0.10226,0.099068,0.0974551,0.0959444,0.0971819,0.0963502,0.0987068,0.0984101,0.100089,0.0989078,0.0979684,0.096737,0.0984465])
speedup=np.array([3.74775,7.85547,11.7483,15.025,16.7928,16.1109,17.9187,17.7179,19.1161,20.1446,17.5956,18.9716,21.0992,20.2761,21.8392,20.3585,22.054,20.9083,21.0263,20.9952,21.6717,22.0304,22.3773,22.0923,22.283,21.751,21.8166,21.4507,21.7068,21.9149,22.1939,21.8085])

i=0
efficiency=[]
for i in range(len(speedup)):
    efficiency.append(speedup[i]/(i+1)) # sppedup// number of processors
plt.plot([i+1 for i in range(len(efficiency))],efficiency,label='10000*10000 Matrix')

plt.title('With SIMD')

plt.xlabel('Number of threads')
plt.ylabel('Efficiency')
plt.legend()
# ex_16=np.array([3.96606,2.42703,1.96869,1.79957,1.59818,1.46364,1.48638,1.39319,1.34778,1.42063,1.27674,1.19111,1.48962,1.5372,1.67119,1.60277,1.62302,1.51426,1.41602,1.70299,1.46983,1.51209,1.74131,1.85786,1.6674,1.90179,1.96685,2.05195,2.0468,2.10766,2.11911,2.19888])
# sp_16=np.array([0.865801,1.41483,1.74421,1.90814,2.14858,2.34608,2.31018,2.46471,2.54775,2.41711,2.68952,2.88288,2.30517,2.23381,2.05472,2.14243,2.11569,2.26765,2.42498,2.01635,2.3362,2.27091,1.97197,1.84826,2.05938,1.80558,1.74585,1.67344,1.67766,1.62921,1.62041,1.56162])
# eff_16=[]
# for i in range(len(sp_16)):
#     eff_16.append(sp_16[i]/(i+1))

# %% [markdown]
# # Why is speedup for larger matrices greater than smaller matrices?​
#
# Initially, adding threads to a multi-threaded program increases speedup because it allows better utilization of all available cores. However, once all cores are fully utilized, adding more threads doesn’t increase the computational power. Instead, it just introduces more context switching and contention for core time, leading to a plateau or even a decrease in speedup.​
#
# Parallelization overheads (e.g., thread creation, synchronization) are relatively constant, regardless of matrix size.​
#
# In larger matrices, the computational workload dominates the overheads, resulting in better speedup.​
#
# For smaller matrices, the overheads become a significant fraction of the total runtime, reducing the net speedup.​
